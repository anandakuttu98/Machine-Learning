# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# %%
data = {'Consumption': [70, 65, 90, 95, 110, 115, 120, 140, 155, 150],
       'Income': [80, 100, 120, 140, 160, 180, 200, 220, 240, 260]}

data_table = pd.DataFrame(data)
data_table
# Out:
#    Consumption  Income
# 0           70      80
# 1           65     100
# 2           90     120
# 3           95     140
# 4          110     160
# 5          115     180
# 6          120     200
# 7          140     220
# 8          155     240
# 9          150     260

# %%
vals = data_table.values
vals
# Out:
# array([[ 70,  80],
#        [ 65, 100],
#        [ 90, 120],
#        [ 95, 140],
#        [110, 160],
#        [115, 180],
#        [120, 200],
#        [140, 220],
#        [155, 240],
#        [150, 260]], dtype=int64)

# %%
plt.scatter(vals[:, 0], vals[:, 1]);

# %%
plt.plot(vals[:,0], vals[:, 1]);

# %%
from sklearn import linear_model
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
x = data_table.iloc[:, :1]
y = data_table.iloc[:, 1:]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (8, 1) (8, 1)
# (2, 1) (2, 1)

# %%
lrm = linear_model.LinearRegression()
lrm_model = lrm.fit(x, y)
lrm_model
# Out:
# LinearRegression()

# %%
lrm_predictions = lrm.predict(x_test)

# %%
lrm_predictions
# Out:
# array([[92.51968504],
#        [83.07086614]])

# %%
print('Score:', lrm_model.score(x_test, y_test))
# Out:
# Score: -1.2166904333808675
